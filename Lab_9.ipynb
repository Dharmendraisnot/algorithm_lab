# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharmendraisnot/algorithm_lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    dist = {node: float('inf') for node in graph}
    prede = {node: None for node in graph}
    visit = []
    dist[start] = 0

    while len(visit) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visit and dist[node] < min_distance:
                min_distance = dist[node]
                min_node = node

        if min_node is None:
            break

        visit.append(min_node)

        for neighbor, weight in graph[min_node].items():
            if neighbor not in visit:
                new_dist = dist[min_node] + weight
                if new_dist < dist[neighbor]:
                    dist[neighbor] = new_dist
                    prede[neighbor] = min_node

    return dist, prede

def get_path(prede, start, end):
    path = []
    curr = end
    while curr is not None:
        path.append(curr)
        curr = prede[curr]
    path.reverse()
    return path if path[0] == start else []

graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 1, 'D': 5},
    'C': {'A': 2, 'B': 1, 'D': 8, 'E': 10},
    'D': {'B': 5, 'C': 8, 'E': 2, 'F': 6},
    'E': {'C': 10, 'D': 2, 'F': 3},
    'F': {'D': 6, 'E': 3}
}

test_sources = ['A', 'D', 'F']

for src in test_sources:
    print(f"\nSource Node: {src}")
    distances, predecessors = dijkstra(graph, src)
    for target in graph:
        if target != src:
            path = get_path(predecessors, src, target)
            path_str = " -> ".join(path)
            print(f"To {target}: {path_str} | Distance: {distances[target]}")
# Out:
# Source Node: A
# To B: A -> C -> B | Distance: 3
# To C: A -> C | Distance: 2
# To D: A -> C -> B -> D | Distance: 8
# To E: A -> C -> B -> D -> E | Distance: 10
# To F: A -> C -> B -> D -> E -> F | Distance: 13
#
# Source Node: D
# To A: D -> B -> C -> A | Distance: 8
# To B: D -> B | Distance: 5
# To C: D -> B -> C | Distance: 6
# To E: D -> E | Distance: 2
# To F: D -> E -> F | Distance: 5
#
# Source Node: F
# To A: F -> E -> D -> B -> C -> A | Distance: 13
# To B: F -> E -> D -> B | Distance: 10
# To C: F -> E -> D -> B -> C | Distance: 11
# To D: F -> E -> D | Distance: 5
# To E: F -> E | Distance: 3
